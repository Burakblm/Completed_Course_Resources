# %% [markdown]
# # Colab Calısma Ortami
#
# *   colab kullanma Ogrenme
# *   ve diger seyler

# %% [markdown]
# # CPU Hakkında

# %%
# !cat /proc/cpuinfo
# Out:
# processor	: 0
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 79
# model name	: Intel(R) Xeon(R) CPU @ 2.20GHz
# stepping	: 0
# microcode	: 0x1
# cpu MHz		: 2199.998
# cache size	: 56320 KB
# physical id	: 0
# siblings	: 2
# core id		: 0
# cpu cores	: 1
# apicid		: 0
# initial apicid	: 0
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm rdseed adx smap xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa
# bogomips	: 4399.99
# clflush size	: 64
# ...

# %% [markdown]
# ### RAM Hakkinda

# %%
# !cat /proc/meminfo
# Out:
# MemTotal:       13302924 kB
# MemFree:        10571640 kB
# MemAvailable:   12502868 kB
# Buffers:          121332 kB
# Cached:          1937472 kB
# SwapCached:            0 kB
# Active:          1011876 kB
# Inactive:        1483476 kB
# Active(anon):     393292 kB
# Inactive(anon):      412 kB
# Active(file):     618584 kB
# Inactive(file):  1483064 kB
# Unevictable:           0 kB
# Mlocked:               0 kB
# SwapTotal:             0 kB
# SwapFree:              0 kB
# Dirty:               284 kB
# Writeback:             0 kB
# AnonPages:        436536 kB
# Mapped:           238060 kB
# Shmem:              1152 kB
# KReclaimable:     142112 kB
# Slab:             186644 kB
# SReclaimable:     142112 kB
# SUnreclaim:        44532 kB
# KernelStack:        4768 kB
# PageTables:         5936 kB
# NFS_Unstable:          0 kB
# Bounce:                0 kB
# WritebackTmp:          0 kB
# CommitLimit:     6651460 kB
# Committed_AS:    3100708 kB
# VmallocTotal:   34359738367 kB
# ...

# %% [markdown]
# # Veri Bilimi
#
# veri bilimi için `python` un farklı kütüphanelerinin kullanalım
#
# `numpy` ve `matplotlib` kütüphanelerini kullanarak bir görselleştirme yapalım

# %%
import numpy as np
from matplotlib import pyplot as plt

ys = 50 + np.random.randn(50)
x = [x for x in range(len(ys))]

plt.plot(x,ys,"*")
plt.fill_between(x,ys,45, where=(ys>45),facecolor="m",alpha=0.5)
plt.title("ornek gosterim")
plt.show()

# %%
# load an example dataset
from vega_datasets import data
cars = data.cars()

# plot the dataset, referencing dataframe column names
import altair as alt
alt.Chart(cars).mark_bar().encode(
  x=alt.X('Miles_per_Gallon', bin=True),
  y='count()',
  color='Origin'
)
# Out:
# alt.Chart(...)

# %%
# load an example dataset
from vega_datasets import data
cars = data.cars()

# plot the dataset, referencing dataframe column names
import altair as alt
alt.Chart(cars).mark_bar().encode(
  x='mean(Miles_per_Gallon)',
  y='Origin',
  color='Origin'
)
# Out:
# alt.Chart(...)

# %%
# load an example dataset
from vega_datasets import data
cars = data.cars()

# plot the dataset, referencing dataframe column names
import altair as alt
alt.Chart(cars).mark_point().encode(
  x='Horsepower',
  y='Miles_per_Gallon',
  color='Origin'
).interactive()
# Out:
# alt.Chart(...)

# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive
# Out:
# Mounted at /gdrive
# /gdrive

# %%
# !ls "/gdrive/MyDrive/Colab Notebooks/"
# Out:
# Colab_calisma_ortami.ipynb  neural_network.ipynb  Untitled0.ipynb

# %%
import os
os.chdir("/gdrive/MyDrive/Colab Notebooks/")

# %%
# !ls
# Out:
# Colab_calisma_ortami.ipynb  neural_network.ipynb  Untitled0.ipynb

# %% [markdown]
# ## GPU Ozelliklerinin Görüntülenmesi

# %%
import tensorflow as tf
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
import tensorflow_hub as hub

# %%
print("TF version: ",tf.__version__)
print("GPU is","available" if tf.test.is_gpu_available() else "NOT available")
# Out:
# TF version:  2.6.0
# WARNING:tensorflow:From <ipython-input-21-ab3ef70591af>:2: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# GPU is NOT available

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 8058421498329004665, name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 11345264640
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 16515850358030425104
#  physical_device_desc: "device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7"]

# %%
# !kill -9 -1
# Out:
# sample_data
