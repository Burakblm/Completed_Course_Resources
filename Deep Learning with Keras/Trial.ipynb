# %%
from google.colab import drive
drive.mount("/gdrive")
# Out:
# Mounted at /gdrive

# %%
import os
os.chdir("/gdrive/My Drive/PYTHON ML/")

# %%
# !ls
# Out:
#  1-veriyukleme.py			 naiv_bayes.py
# '3.1 - verionislemesablonu.py'		 natural_language_processing.py
# '3.3 -dogrusalregresyonhazirlik.py'	 odev2.py
# '3.4 -dogrusalregresyonmodelinsasi.py'	 odev_cozum_hazirlik.py
#  Ads_CTR_Optimisation.csv		 odev_cozum.py
#  apriori.py				 odev_tenis_cozum.py
#  apyori.py				 odev_tenis.csv
#  Churn_Modelling.csv			 odev_tenis.py
#  Classifier_comparison.py		 polinom_regresyon_şablonu.py
#  cnn.py					 Principal_component_analysis.py
#  Convolutional_neural_network		 python_mlr_hazırlık.py
#  csv_dosyası_hazırlama.py		 python_mlr_tahmin.py
#  Decision_tree				 random_forest_classifier.py
#  deneme.py				 random_forest_regressor.py
#  derin_ögrenme.py			 random.py
#  desicion_tree_classifier.py		 rastgele_kelime_uretici.py
#  dogrusalregresyon_gorsellestirme.py	 Restaurant_Reviews2.csv
#  dosya_hazırlama.py			 Restaurant_Reviews.csv
#  egitilmis_veriyi_kayit_etme.py		 satislar.csv
#  eksikveriler.csv			 sepet.csv
# ...

# %%
# Out:
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
