# %%
from google.colab import drive
drive.mount("/gdrive")
# %cd /gdrive
# Out:
# Mounted at /gdrive
# /gdrive

# %%
import os
os.chdir("/gdrive/My Drive/")

# %%
# !ls
# Out:
#  aktivasyon_fonksiyonları.ipynb     MNIST_YSA.ipynb
#  Colab_calisma_ortami.ipynb	   'neural_network (1).ipynb'
#  DuyguTanıma.ipynb		    ResNET50_NesneTanıma_ImageNet.ipynb
#  EvrişimliSinirAğı_AdımAdım.ipynb   Uygulama_Rakam_Tanıma.ipynb
#  Fashion_MNIST_CNN.ipynb	    Vektorler_Matrisler_Tensorler.ipynb
#  Katmanlar_ve_Modeller.ipynb	    VGG16_NesneTanıma.ipynb

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline

import keras
from keras.models import Sequential, Model, model_from_json
from keras.layers import Dense, Conv2D, Activation, MaxPool2D, Flatten, Dropout, BatchNormalization
from keras.utils import np_utils
from keras.preprocessing import image
from keras.callbacks import ModelCheckpoint
